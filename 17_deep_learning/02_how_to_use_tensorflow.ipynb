# %% [markdown]
# # How to use Tensorflow 2

# %% [markdown]
# Keras was designed as a high-level or meta API to accelerate the iterative workflow when designing and training deep neural networks with computational backends like TensorFlow, Theano, or CNTK. It has been integrated into TensorFlow in 2017 and is set to become the principal TensorFlow interface with the 2.0 release. You can also combine code from both libraries to leverage Keras’ high-level abstractions as well as customized TensorFlow graph operations.

# %% [markdown]
# Please follow the installations instructions in `Installation Guide.md` in the root folder.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_circles # To generate the dataset
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns

# %%
# plotting style
sns.set_style('darkgrid')
# for reproducibility
np.random.seed(seed=42)

# %% [markdown]
# ## Input Data

# %% [markdown]
# ### Generate random data

# %% [markdown]
# The target `y` represents two classes generated by two circular distribution that are not linearly separable because class 0 surrounds class 1.

# %%
# dataset params
N = 50000
factor = 0.1
noise = 0.1

# %%
# generate data
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# ### Visualize Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

# %% [markdown]
# ## Build Keras Model

# %% [markdown]
# Keras supports both a slightly simpler Sequential and more flexible Functional API. We will introduce the former at this point and use the Functional API in more complex examples in the following chapters.
#
# To create a model, we just need to instantiate a Sequential object and provide a list with the sequence of standard layers and their configurations, including the number of units, type of activation function, or name.

# %% [markdown]
# ### Define Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])

# %% [markdown]
# The first hidden layer needs information about the number of features in the matrix it receives from the input layer via the input_shape argument. In our simple case, these are just two. Keras infers the number of rows it needs to process during training, through the batch_size argument that we will pass to the fit method below.
#
# Keras infers the sizes of the inputs received by other layers from the previous layer’s units argument.

# %% [markdown]
# Keras provides numerous standard building blocks, including recurrent and convolutional layers, various options for regularization, a range of loss functions and optimizers, and also preprocessing, visualization and logging (see documentation on GitHub for reference). It is also extensible.
#
# The model’s summary method produces a concise description of the network architecture, including a list of the layer types and shapes, and the number of parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 3)                 9
# _________________________________________________________________
# logistic (Activation)        (None, 3)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 8
# _________________________________________________________________
# softmax (Activation)         (None, 2)                 0
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %% [markdown]
# Next, we compile the Sequential model to configure the learning process. To this end, we define the optimizer, the loss function, and one or several performance metrics to monitor during training:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Tensorboard Callback

# %% [markdown]
# Keras uses callbacks to enable certain functionality during training, such as logging information for interactive display in TensorBoard (see next section):

# %%
tb_callback = TensorBoard(log_dir='./tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# ## Train Model

# %% [markdown]
# To train the model, we call its fit method and pass several parameters in addition to the training data:

# %%
training=model.fit(X, 
          Y, 
          epochs=50,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 1s 29us/sample - loss: 0.6931 - accuracy: 0.5627 - val_loss: 0.6921 - val_accuracy: 0.6972
# Epoch 2/50
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.6900 - accuracy: 0.6879 - val_loss: 0.6881 - val_accuracy: 0.6281
# Epoch 3/50
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.6849 - accuracy: 0.6765 - val_loss: 0.6814 - val_accuracy: 0.7069
# Epoch 4/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.6747 - accuracy: 0.7083 - val_loss: 0.6671 - val_accuracy: 0.7189
# Epoch 5/50
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.6554 - accuracy: 0.7441 - val_loss: 0.6425 - val_accuracy: 0.7810
# Epoch 6/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.6237 - accuracy: 0.8072 - val_loss: 0.6052 - val_accuracy: 0.8366
# Epoch 7/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 0.5797 - accuracy: 0.8586 - val_loss: 0.5564 - val_accuracy: 0.8627
# Epoch 8/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.5272 - accuracy: 0.8786 - val_loss: 0.5028 - val_accuracy: 0.8816
# Epoch 9/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.4712 - accuracy: 0.8959 - val_loss: 0.4454 - val_accuracy: 0.8963
# Epoch 10/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.4132 - accuracy: 0.9120 - val_loss: 0.3872 - val_accuracy: 0.9147
# Epoch 11/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.3541 - accuracy: 0.9305 - val_loss: 0.3268 - val_accuracy: 0.9357
# Epoch 12/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.2940 - accuracy: 0.9573 - val_loss: 0.2663 - val_accuracy: 0.9766
# Epoch 13/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 0.2365 - accuracy: 0.9903 - val_loss: 0.2110 - val_accuracy: 0.9973
# Epoch 14/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 0.1854 - accuracy: 0.9992 - val_loss: 0.1633 - val_accuracy: 0.9999
# Epoch 15/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.1422 - accuracy: 0.9999 - val_loss: 0.1241 - val_accuracy: 1.0000
# Epoch 16/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.1078 - accuracy: 0.9999 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 17/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 0.0809 - accuracy: 0.9999 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 18/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0605 - accuracy: 0.9999 - val_loss: 0.0521 - val_accuracy: 1.0000
# Epoch 19/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0451 - accuracy: 0.9999 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 20/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0336 - accuracy: 0.9999 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 21/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0252 - accuracy: 0.9999 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 22/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0189 - accuracy: 0.9999 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 23/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0144 - accuracy: 0.9999 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 24/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0110 - accuracy: 0.9999 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 25/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0084 - accuracy: 0.9999 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 26/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0066 - accuracy: 0.9999 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 27/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 28/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0042 - accuracy: 0.9999 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 29/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0034 - accuracy: 0.9999 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 30/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 31/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 32/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 33/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 34/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 35/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 36/50
# 40000/40000 [==============================] - 1s 19us/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 37/50
# 40000/40000 [==============================] - 1s 19us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.1574e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 9.3975e-04 - accuracy: 0.9999 - val_loss: 8.2628e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 8.5206e-04 - accuracy: 0.9999 - val_loss: 7.5436e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 7.8667e-04 - accuracy: 0.9999 - val_loss: 6.8692e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 7.2739e-04 - accuracy: 0.9999 - val_loss: 6.3252e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 6.7099e-04 - accuracy: 0.9999 - val_loss: 5.8156e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 6.2671e-04 - accuracy: 0.9999 - val_loss: 5.4320e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 5.9122e-04 - accuracy: 1.0000 - val_loss: 5.1258e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 5.5865e-04 - accuracy: 1.0000 - val_loss: 4.7881e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 5.2797e-04 - accuracy: 1.0000 - val_loss: 4.5363e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 40000/40000 [==============================] - 1s 18us/sample - loss: 5.0349e-04 - accuracy: 1.0000 - val_loss: 4.2862e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 40000/40000 [==============================] - 1s 16us/sample - loss: 4.8257e-04 - accuracy: 0.9999 - val_loss: 4.0645e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 4.6092e-04 - accuracy: 1.0000 - val_loss: 3.8227e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 40000/40000 [==============================] - 1s 17us/sample - loss: 4.3892e-04 - accuracy: 0.9999 - val_loss: 3.6655e-04 - val_accuracy: 1.0000

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
fig.tight_layout();

# %% [markdown]
# ## Get Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# ## Plot Decision Boundary

# %% [markdown]
# The visualization of the decision boundary resembles the result from the manual network implementation. The training with Keras runs a multiple faster, though.

# %%
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)

# %%
# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir tensorboard/
# Out:
#       <iframe id="tensorboard-frame-379f92f1127066c6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-379f92f1127066c6");
#           const url = new URL("/", window.location);
#           url.port = 6007;
#           frame.src = url;
#         })();
#       </script>
