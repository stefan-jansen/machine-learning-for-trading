# %% [markdown]
# # How to use Keras

# %% [markdown]
# Keras was designed as a high-level or meta API to accelerate the iterative workflow when designing and training deep neural networks with computational backends like TensorFlow, Theano, or CNTK. It has been integrated into TensorFlow in 2017 and is set to become the principal TensorFlow interface with the 2.0 release. You can also combine code from both libraries to leverage Keras’ high-level abstractions as well as customized TensorFlow graph operations.

# %% [markdown]
# Please follow the installations instructions in `Installation Guide.md` in the root folder.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_circles # To generate the dataset
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns

# %%
# plotting style
sns.set_style('darkgrid')
# for reproducibility
np.random.seed(seed=42)

# %% [markdown]
# ## Input Data

# %% [markdown]
# ### Generate random data

# %% [markdown]
# The target `y` represents two classes generated by two circular distribution that are not linearly separable because class 0 surrounds class 1.

# %%
# dataset params
N = 50000
factor = 0.1
noise = 0.1

# %%
# generate data
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# ### Visualize Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

# %% [markdown]
# ## Build Keras Model

# %% [markdown]
# Keras supports both a slightly simpler Sequential and more flexible Functional API. We will introduce the former at this point and use the Functional API in more complex examples in the following chapters.
#
# To create a model, we just need to instantiate a Sequential object and provide a list with the sequence of standard layers and their configurations, including the number of units, type of activation function, or name.

# %% [markdown]
# ### Define Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])

# %% [markdown]
# The first hidden layer needs information about the number of features in the matrix it receives from the input layer via the input_shape argument. In our simple case, these are just two. Keras infers the number of rows it needs to process during training, through the batch_size argument that we will pass to the fit method below.
#
# Keras infers the sizes of the inputs received by other layers from the previous layer’s units argument.

# %% [markdown]
# Keras provides numerous standard building blocks, including recurrent and convolutional layers, various options for regularization, a range of loss functions and optimizers, and also preprocessing, visualization and logging (see documentation on GitHub for reference). It is also extensible.
#
# The model’s summary method produces a concise description of the network architecture, including a list of the layer types and shapes, and the number of parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 3)                 9
# _________________________________________________________________
# logistic (Activation)        (None, 3)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 8
# _________________________________________________________________
# softmax (Activation)         (None, 2)                 0
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %% [markdown]
# Next, we compile the Sequential model to configure the learning process. To this end, we define the optimizer, the loss function, and one or several performance metrics to monitor during training:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Tensorboard Callback

# %% [markdown]
# Keras uses callbacks to enable certain functionality during training, such as logging information for interactive display in TensorBoard (see next section):

# %%
tb_callback = TensorBoard(log_dir='./tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# ## Train Model

# %% [markdown]
# To train the model, we call its fit method and pass several parameters in addition to the training data:

# %%
model.fit(X, 
          Y, 
          epochs=25,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/25
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.7104 - accuracy: 0.4500 - val_loss: 0.6927 - val_accuracy: 0.5727
# Epoch 2/25
# 40000/40000 [==============================] - 1s 19us/sample - loss: 0.6909 - accuracy: 0.6025 - val_loss: 0.6893 - val_accuracy: 0.4826
# Epoch 3/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.6862 - accuracy: 0.6417 - val_loss: 0.6822 - val_accuracy: 0.5362
# Epoch 4/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.6756 - accuracy: 0.7447 - val_loss: 0.6671 - val_accuracy: 0.8581
# Epoch 5/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.6546 - accuracy: 0.8724 - val_loss: 0.6399 - val_accuracy: 0.8841
# Epoch 6/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.6215 - accuracy: 0.8897 - val_loss: 0.6008 - val_accuracy: 0.8879
# Epoch 7/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.5765 - accuracy: 0.8946 - val_loss: 0.5504 - val_accuracy: 0.9011
# Epoch 8/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.5235 - accuracy: 0.9017 - val_loss: 0.4951 - val_accuracy: 0.9004
# Epoch 9/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.4667 - accuracy: 0.9056 - val_loss: 0.4365 - val_accuracy: 0.9146
# Epoch 10/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.4079 - accuracy: 0.9157 - val_loss: 0.3774 - val_accuracy: 0.9211
# Epoch 11/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.3487 - accuracy: 0.9259 - val_loss: 0.3186 - val_accuracy: 0.9347
# Epoch 12/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.2914 - accuracy: 0.9407 - val_loss: 0.2630 - val_accuracy: 0.9470
# Epoch 13/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.2381 - accuracy: 0.9628 - val_loss: 0.2126 - val_accuracy: 0.9786
# Epoch 14/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.1911 - accuracy: 0.9890 - val_loss: 0.1693 - val_accuracy: 0.9954
# Epoch 15/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.1509 - accuracy: 0.9980 - val_loss: 0.1326 - val_accuracy: 0.9988
# Epoch 16/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.1176 - accuracy: 0.9995 - val_loss: 0.1029 - val_accuracy: 0.9997
# Epoch 17/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.0905 - accuracy: 0.9999 - val_loss: 0.0787 - val_accuracy: 0.9997
# Epoch 18/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.0690 - accuracy: 0.9999 - val_loss: 0.0598 - val_accuracy: 0.9999
# Epoch 19/25
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0522 - accuracy: 0.9999 - val_loss: 0.0451 - val_accuracy: 0.9999
# Epoch 20/25
# 40000/40000 [==============================] - 1s 15us/sample - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9999
# Epoch 21/25
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9999
# Epoch 22/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9999
# Epoch 23/25
# 40000/40000 [==============================] - 1s 14us/sample - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9999
# Epoch 24/25
# 40000/40000 [==============================] - 1s 16us/sample - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9999
# Epoch 25/25
# 40000/40000 [==============================] - 1s 17us/sample - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9999

# %% [markdown]
# ## Get Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# ## Plot Decision Boundary

# %% [markdown]
# The visualization of the decision boundary resembles the result from the manual network implementation. The training with Keras runs a multiple faster, though.

# %%
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)

# %%
# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir tensorboard/
# Out:
#       <iframe id="tensorboard-frame-d26fd39df49efe98" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d26fd39df49efe98");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
