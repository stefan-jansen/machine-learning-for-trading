# %% [markdown]
# # Basic Image Classification with Feedforward NN and LetNet5

# %% [markdown]
# All libraries we introduced in the last chapter provide support for convolutional layers. We are going to illustrate the LeNet5 architecture using the most basic MNIST handwritten digit dataset, and then use AlexNet on CIFAR10, a simplified version of the original ImageNet to demonstrate the use of data augmentation.
# LeNet5 and MNIST using Keras.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
from random import randint
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Dense, Dropout, Flatten
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ## Load MNIST Database

# %% [markdown]
# The original MNIST dataset contains 60,000 images in 28x28 pixel resolution with a single grayscale containing handwritten digits from 0 to 9. A good alternative is the more challenging but structurally similar Fashion MNIST dataset that we encountered in Chapter 12 on Unsupervised Learning.

# %% [markdown]
# We can load it in keras out of the box:

# %%
# use Keras to import pre-shuffled MNIST database
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("The MNIST database has a training set of %d examples." % len(X_train))
print("The MNIST database has a test set of %d examples." % len(X_test))
# Out:
# The MNIST database has a training set of 60000 examples.
# The MNIST database has a test set of 10000 examples.

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### Visualize First 10 Training Images

# %% [markdown]
# The below figure shows the first ten images in the dataset and highlights significant variation among instances of the same digit. On the right, it shows how the pixel values for an indivual image range from 0 to 255.

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(20, 8))
axes = axes.flatten()
for i, ax in enumerate(axes):
    ax.imshow(X_train[i], cmap='gray')
    ax.axis('off')
    ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)
fig.suptitle('First 10 Digits', fontsize=20)
fig.tight_layout()
fig.subplots_adjust(top=.9)

# %% [markdown]
# ### Show random image in detail

# %%
fig, ax = plt.subplots(figsize = (14, 14)) 

i = randint(0, len(X_train))
img = X_train[i]

ax.imshow(img, cmap='gray')
ax.set_title('Digit: {}'.format(y_train[i]), fontsize=16)

width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        ax.annotate('{:2}'.format(img[x][y]), 
                    xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Rescale pixel values

# %% [markdown]
# We rescale the pixel values to the range [0, 1] to normalize the training data and faciliate the backpropagation process and convert the data to 32 bit floats that reduce memory requirements and computational cost while providing sufficient precision for our use case:

# %%
# rescale [0,255] --> [0,1]
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %% [markdown]
# ### One-Hot Label Encoding using Keras

# %% [markdown]
# Print first ten labels

# %%
print('Integer-valued labels:')
print(y_train[:10])
# Out:
# Integer-valued labels:
# [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ## Feed-Forward NN

# %% [markdown]
# ### Model Architecture

# %%
ffnn = Sequential([
    Flatten(input_shape=X_train.shape[1:]),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %%
ffnn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
ffnn.compile(loss='sparse_categorical_crossentropy', 
              optimizer='rmsprop', 
              metrics=['accuracy'])

# %% [markdown]
# ### Calculate Baseline Classification Accuracy

# %%
# evaluate test accuracy
baseline_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

# print test accuracy
print(f'Test accuracy: {baseline_accuracy:.2%}')
# Out:
# Test accuracy: 11.46%

# %% [markdown]
# ### Callback for model persistence

# %%
mnist_path = 'models/mnist.ffn.best.hdf5'

# %%
checkpointer = ModelCheckpoint(filepath=mnist_path, 
                               verbose=1, 
                               save_best_only=True)

# %% [markdown]
# ### Early Stopping Callback

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# %% [markdown]
# ### Train the Model

# %%
epochs = 100
batch_size = 32

# %%
ffnn_history = ffnn.fit(X_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=0.2,
                        callbacks=[checkpointer, early_stopping],
                        verbose=1,
                        shuffle=True)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.2409 - accuracy: 0.9274
# Epoch 00001: val_loss improved from inf to 0.13248, saving model to models/mnist.ffn.best.hdf5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.2393 - accuracy: 0.9279 - val_loss: 0.1325 - val_accuracy: 0.9641
# Epoch 2/100
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1285 - accuracy: 0.9665
# Epoch 00002: val_loss improved from 0.13248 to 0.13076, saving model to models/mnist.ffn.best.hdf5
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1284 - accuracy: 0.9665 - val_loss: 0.1308 - val_accuracy: 0.9683
# Epoch 3/100
# 46912/48000 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9731
# Epoch 00003: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1154 - accuracy: 0.9731 - val_loss: 0.1357 - val_accuracy: 0.9728
# Epoch 4/100
# 47296/48000 [============================>.] - ETA: 0s - loss: 0.1063 - accuracy: 0.9759
# Epoch 00004: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1068 - accuracy: 0.9759 - val_loss: 0.1518 - val_accuracy: 0.9722
# Epoch 5/100
# 47936/48000 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9779
# Epoch 00005: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1036 - accuracy: 0.9780 - val_loss: 0.1596 - val_accuracy: 0.9739
# Epoch 6/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.1009 - accuracy: 0.9792
# Epoch 00006: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1006 - accuracy: 0.9793 - val_loss: 0.2345 - val_accuracy: 0.9710
# Epoch 7/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9809
# Epoch 00007: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.0972 - accuracy: 0.9807 - val_loss: 0.1501 - val_accuracy: 0.9778
# Epoch 8/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0863 - accuracy: 0.9832
# Epoch 00008: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0881 - accuracy: 0.9830 - val_loss: 0.1664 - val_accuracy: 0.9767
# Epoch 9/100
# 47552/48000 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9834
# Epoch 00009: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0911 - accuracy: 0.9833 - val_loss: 0.1477 - val_accuracy: 0.9777
# Epoch 10/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9838
# Epoch 00010: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0882 - accuracy: 0.9838 - val_loss: 0.2159 - val_accuracy: 0.9743
# Epoch 11/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9849
# Epoch 00011: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0868 - accuracy: 0.9850 - val_loss: 0.2208 - val_accuracy: 0.9791
# Epoch 12/100
# 47616/48000 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9854
# Epoch 00012: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0829 - accuracy: 0.9855 - val_loss: 0.2490 - val_accuracy: 0.9756
# Epoch 13/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0895 - accuracy: 0.9855
# Epoch 00013: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0894 - accuracy: 0.9854 - val_loss: 0.2191 - val_accuracy: 0.9782
# Epoch 14/100
# 47552/48000 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9864
# Epoch 00014: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0806 - accuracy: 0.9864 - val_loss: 0.2713 - val_accuracy: 0.9772
# Epoch 15/100
# 46976/48000 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9872
# Epoch 00015: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0821 - accuracy: 0.9872 - val_loss: 0.2447 - val_accuracy: 0.9789
# Epoch 16/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9873
# Epoch 00016: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0812 - accuracy: 0.9873 - val_loss: 0.2677 - val_accuracy: 0.9779
# Epoch 17/100
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9878
# Epoch 00017: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0788 - accuracy: 0.9878 - val_loss: 0.2504 - val_accuracy: 0.9799
# Epoch 18/100
# 47584/48000 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9884
# Epoch 00018: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0748 - accuracy: 0.9884 - val_loss: 0.2774 - val_accuracy: 0.9803
# Epoch 19/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9892
# Epoch 00019: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0714 - accuracy: 0.9892 - val_loss: 0.2730 - val_accuracy: 0.9787
# Epoch 20/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9889
# Epoch 00020: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0707 - accuracy: 0.9889 - val_loss: 0.2875 - val_accuracy: 0.9798
# Epoch 21/100
# 47520/48000 [============================>.] - ETA: 0s - loss: 0.0730 - accuracy: 0.9899
# Epoch 00021: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0726 - accuracy: 0.9899 - val_loss: 0.3621 - val_accuracy: 0.9800
# Epoch 22/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9900
# Epoch 00022: val_loss did not improve from 0.13076
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.0710 - accuracy: 0.9900 - val_loss: 0.3239 - val_accuracy: 0.9791

# %% [markdown]
# ### Plot CV Results

# %%
pd.DataFrame(ffnn_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4));

# %% [markdown]
# ### Load the Best Model

# %%
# load the weights that yielded the best validation accuracy
ffnn.load_weights(mnist_path)

# %% [markdown]
# ### Test Classification Accuracy

# %%
# evaluate test accuracy
ffnn_accuracy = ffnn.evaluate(X_test, y_test, verbose=0)[1]

print(f'Test accuracy: {ffnn_accuracy:.2%}')
# Out:
# Test accuracy: 97.05%

# %% [markdown]
# ## LeNet5

# %%
K.clear_session()

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# We can define a simplified version of LeNet5 that omits the original final layer containing radial basis functions as follows, using the default ‘valid’ padding and single step strides unless defined otherwise:

# %%
lenet5 = Sequential([
    Conv2D(filters=6,
           kernel_size=5,
           activation='relu',
           input_shape=(28, 28, 1),
           name='CONV1'),
    AveragePooling2D(pool_size=(2, 2),
                     strides=(1, 1),
                     padding='valid',
                     name='POOL1'),
    Conv2D(filters=16, kernel_size=(5, 5), activation='tanh', name='CONV2'),
    AveragePooling2D(pool_size=(2, 2), strides=(2, 2), name='POOL2'),
    Conv2D(filters=120, kernel_size=(5, 5), activation='tanh', name='CONV3'),
    Flatten(name='FLAT'),
    Dense(units=84, activation='tanh', name='FC6'),
    Dense(units=10, activation='softmax', name='FC7')
])

# %% [markdown]
# The summary indicates that the model thus defined has over 300,000 parameters:

# %%
lenet5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# CONV1 (Conv2D)               (None, 24, 24, 6)         156
# _________________________________________________________________
# POOL1 (AveragePooling2D)     (None, 23, 23, 6)         0
# _________________________________________________________________
# CONV2 (Conv2D)               (None, 19, 19, 16)        2416
# _________________________________________________________________
# POOL2 (AveragePooling2D)     (None, 9, 9, 16)          0
# _________________________________________________________________
# CONV3 (Conv2D)               (None, 5, 5, 120)         48120
# _________________________________________________________________
# FLAT (Flatten)               (None, 3000)              0
# _________________________________________________________________
# FC6 (Dense)                  (None, 84)                252084
# _________________________________________________________________
# FC7 (Dense)                  (None, 10)                850
# =================================================================
# Total params: 303,626
# Trainable params: 303,626
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We compile using crossentropy loss and the original stochastic gradient optimizer:

# %%
lenet5.compile(loss='sparse_categorical_crossentropy',
               optimizer='SGD',
               metrics=['accuracy'])

# %% [markdown]
# ### Define checkpoint callback

# %%
lenet_path = 'models/mnist.lenet.best.hdf5'

# %%
checkpointer = ModelCheckpoint(filepath=lenet_path,
                               verbose=1,
                               save_best_only=True)

# %% [markdown]
# Now we are ready to train the model. The model expects 4D input so we reshape accordingly. We use the standard batch size of 32, 80-20 train-validation split, use checkpointing to store the model weights if the validation error improves, and make sure the dataset is randomly shuffled:

# %% [markdown]
# ### Train Model

# %%
batch_size=32
epochs=100

# %%
lenet_history = lenet5.fit(
    X_train.reshape(-1, 28, 28, 1),
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,  # use 0 to train on all data
    callbacks=[checkpointer, early_stopping],
    verbose=1,
    shuffle=True)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.4724 - accuracy: 0.8687
# Epoch 00001: val_loss improved from inf to 0.24929, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.4713 - accuracy: 0.8690 - val_loss: 0.2493 - val_accuracy: 0.9272
# Epoch 2/100
# 47904/48000 [============================>.] - ETA: 0s - loss: 0.2075 - accuracy: 0.9409
# Epoch 00002: val_loss improved from 0.24929 to 0.16762, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.2075 - accuracy: 0.9409 - val_loss: 0.1676 - val_accuracy: 0.9525
# Epoch 3/100
# 47904/48000 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9579
# Epoch 00003: val_loss improved from 0.16762 to 0.12071, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.1464 - accuracy: 0.9579 - val_loss: 0.1207 - val_accuracy: 0.9658
# Epoch 4/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.1131 - accuracy: 0.9676
# Epoch 00004: val_loss improved from 0.12071 to 0.09940, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.1124 - accuracy: 0.9678 - val_loss: 0.0994 - val_accuracy: 0.9720
# Epoch 5/100
# 47488/48000 [============================>.] - ETA: 0s - loss: 0.0916 - accuracy: 0.9737
# Epoch 00005: val_loss improved from 0.09940 to 0.09208, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0915 - accuracy: 0.9738 - val_loss: 0.0921 - val_accuracy: 0.9733
# Epoch 6/100
# 46912/48000 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9771
# Epoch 00006: val_loss improved from 0.09208 to 0.07691, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.0780 - accuracy: 0.9771 - val_loss: 0.0769 - val_accuracy: 0.9787
# Epoch 7/100
# 47072/48000 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.9806
# Epoch 00007: val_loss improved from 0.07691 to 0.06981, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.0678 - accuracy: 0.9807 - val_loss: 0.0698 - val_accuracy: 0.9795
# Epoch 8/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9827
# Epoch 00008: val_loss improved from 0.06981 to 0.06695, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0604 - accuracy: 0.9827 - val_loss: 0.0670 - val_accuracy: 0.9806
# Epoch 9/100
# 47808/48000 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9847
# Epoch 00009: val_loss improved from 0.06695 to 0.06423, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0546 - accuracy: 0.9847 - val_loss: 0.0642 - val_accuracy: 0.9818
# Epoch 10/100
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9860
# Epoch 00010: val_loss improved from 0.06423 to 0.05798, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0495 - accuracy: 0.9860 - val_loss: 0.0580 - val_accuracy: 0.9827
# Epoch 11/100
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9872
# Epoch 00011: val_loss did not improve from 0.05798
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0455 - accuracy: 0.9872 - val_loss: 0.0611 - val_accuracy: 0.9825
# Epoch 12/100
# 47072/48000 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9884
# Epoch 00012: val_loss did not improve from 0.05798
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0420 - accuracy: 0.9885 - val_loss: 0.0625 - val_accuracy: 0.9825
# Epoch 13/100
# 47904/48000 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9894
# Epoch 00013: val_loss improved from 0.05798 to 0.05472, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0393 - accuracy: 0.9894 - val_loss: 0.0547 - val_accuracy: 0.9828
# Epoch 14/100
# 47744/48000 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9898
# Epoch 00014: val_loss did not improve from 0.05472
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0365 - accuracy: 0.9898 - val_loss: 0.0560 - val_accuracy: 0.9835
# Epoch 15/100
# 47936/48000 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9912
# Epoch 00015: val_loss improved from 0.05472 to 0.05333, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0341 - accuracy: 0.9911 - val_loss: 0.0533 - val_accuracy: 0.9841
# Epoch 16/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9914
# Epoch 00016: val_loss improved from 0.05333 to 0.04817, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0317 - accuracy: 0.9913 - val_loss: 0.0482 - val_accuracy: 0.9862
# Epoch 17/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9919
# Epoch 00017: val_loss did not improve from 0.04817
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0299 - accuracy: 0.9920 - val_loss: 0.0498 - val_accuracy: 0.9860
# Epoch 18/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9926
# Epoch 00018: val_loss improved from 0.04817 to 0.04759, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0283 - accuracy: 0.9927 - val_loss: 0.0476 - val_accuracy: 0.9862
# Epoch 19/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9932
# Epoch 00019: val_loss improved from 0.04759 to 0.04749, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0265 - accuracy: 0.9933 - val_loss: 0.0475 - val_accuracy: 0.9862
# Epoch 20/100
# 47520/48000 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9935
# Epoch 00020: val_loss improved from 0.04749 to 0.04506, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0252 - accuracy: 0.9935 - val_loss: 0.0451 - val_accuracy: 0.9872
# Epoch 21/100
# 47072/48000 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9937
# Epoch 00021: val_loss improved from 0.04506 to 0.04352, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.0435 - val_accuracy: 0.9876
# Epoch 22/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9943
# Epoch 00022: val_loss did not improve from 0.04352
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0224 - accuracy: 0.9943 - val_loss: 0.0445 - val_accuracy: 0.9874
# Epoch 23/100
# 47840/48000 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9945
# Epoch 00023: val_loss did not improve from 0.04352
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0214 - accuracy: 0.9945 - val_loss: 0.0437 - val_accuracy: 0.9871
# Epoch 24/100
# 47840/48000 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9949
# Epoch 00024: val_loss did not improve from 0.04352
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0203 - accuracy: 0.9949 - val_loss: 0.0441 - val_accuracy: 0.9877
# Epoch 25/100
# 47840/48000 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9953
# Epoch 00025: val_loss improved from 0.04352 to 0.04292, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0192 - accuracy: 0.9953 - val_loss: 0.0429 - val_accuracy: 0.9880
# Epoch 26/100
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9954
# Epoch 00026: val_loss improved from 0.04292 to 0.04217, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.0182 - accuracy: 0.9953 - val_loss: 0.0422 - val_accuracy: 0.9883
# Epoch 27/100
# 47424/48000 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9958
# Epoch 00027: val_loss improved from 0.04217 to 0.04011, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0174 - accuracy: 0.9959 - val_loss: 0.0401 - val_accuracy: 0.9886
# Epoch 28/100
# 47136/48000 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9959
# Epoch 00028: val_loss did not improve from 0.04011
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0164 - accuracy: 0.9959 - val_loss: 0.0437 - val_accuracy: 0.9866
# Epoch 29/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9969
# Epoch 00029: val_loss did not improve from 0.04011
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0156 - accuracy: 0.9969 - val_loss: 0.0410 - val_accuracy: 0.9878
# Epoch 30/100
# 47488/48000 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9967
# Epoch 00030: val_loss improved from 0.04011 to 0.03999, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0150 - accuracy: 0.9967 - val_loss: 0.0400 - val_accuracy: 0.9884
# Epoch 31/100
# 47904/48000 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9968
# Epoch 00031: val_loss did not improve from 0.03999
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0143 - accuracy: 0.9968 - val_loss: 0.0402 - val_accuracy: 0.9884
# Epoch 32/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9973
# Epoch 00032: val_loss improved from 0.03999 to 0.03935, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0135 - accuracy: 0.9973 - val_loss: 0.0393 - val_accuracy: 0.9885
# Epoch 33/100
# 46944/48000 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9974
# Epoch 00033: val_loss did not improve from 0.03935
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.0401 - val_accuracy: 0.9887
# Epoch 34/100
# 47136/48000 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9976
# Epoch 00034: val_loss improved from 0.03935 to 0.03923, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0125 - accuracy: 0.9976 - val_loss: 0.0392 - val_accuracy: 0.9887
# Epoch 35/100
# 47488/48000 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9977
# Epoch 00035: val_loss did not improve from 0.03923
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0118 - accuracy: 0.9977 - val_loss: 0.0412 - val_accuracy: 0.9889
# Epoch 36/100
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9982
# Epoch 00036: val_loss did not improve from 0.03923
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0112 - accuracy: 0.9982 - val_loss: 0.0393 - val_accuracy: 0.9893
# Epoch 37/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9980
# Epoch 00037: val_loss did not improve from 0.03923
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0110 - accuracy: 0.9980 - val_loss: 0.0397 - val_accuracy: 0.9883
# Epoch 38/100
# 46912/48000 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9982
# Epoch 00038: val_loss improved from 0.03923 to 0.03850, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.0385 - val_accuracy: 0.9891
# Epoch 39/100
# 47648/48000 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9984
# Epoch 00039: val_loss did not improve from 0.03850
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.0390 - val_accuracy: 0.9889
# Epoch 40/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9985
# Epoch 00040: val_loss improved from 0.03850 to 0.03766, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0096 - accuracy: 0.9985 - val_loss: 0.0377 - val_accuracy: 0.9893
# Epoch 41/100
# 47680/48000 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9986
# Epoch 00041: val_loss did not improve from 0.03766
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.0380 - val_accuracy: 0.9892
# Epoch 42/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9987
# Epoch 00042: val_loss did not improve from 0.03766
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.0388 - val_accuracy: 0.9893
# Epoch 43/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9988
# Epoch 00043: val_loss did not improve from 0.03766
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.0384 - val_accuracy: 0.9894
# Epoch 44/100
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9989
# Epoch 00044: val_loss did not improve from 0.03766
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0382 - val_accuracy: 0.9893
# Epoch 45/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9989
# Epoch 00045: val_loss did not improve from 0.03766
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0079 - accuracy: 0.9989 - val_loss: 0.0381 - val_accuracy: 0.9893
# Epoch 46/100
# 46976/48000 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9989
# Epoch 00046: val_loss improved from 0.03766 to 0.03730, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0076 - accuracy: 0.9989 - val_loss: 0.0373 - val_accuracy: 0.9895
# Epoch 47/100
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9989
# Epoch 00047: val_loss did not improve from 0.03730
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.0383 - val_accuracy: 0.9893
# Epoch 48/100
# 47744/48000 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9992
# Epoch 00048: val_loss did not improve from 0.03730
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.0374 - val_accuracy: 0.9895
# Epoch 49/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9992
# Epoch 00049: val_loss did not improve from 0.03730
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0374 - val_accuracy: 0.9895
# Epoch 50/100
# 47072/48000 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9992
# Epoch 00050: val_loss did not improve from 0.03730
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0374 - val_accuracy: 0.9892
# Epoch 51/100
# 47136/48000 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9991
# Epoch 00051: val_loss improved from 0.03730 to 0.03687, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.0369 - val_accuracy: 0.9898
# Epoch 52/100
# 47744/48000 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9993
# Epoch 00052: val_loss did not improve from 0.03687
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.0372 - val_accuracy: 0.9898
# Epoch 53/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9994
# Epoch 00053: val_loss improved from 0.03687 to 0.03670, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.0367 - val_accuracy: 0.9899
# Epoch 54/100
# 47136/48000 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9994
# Epoch 00054: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0057 - accuracy: 0.9994 - val_loss: 0.0375 - val_accuracy: 0.9891
# Epoch 55/100
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9994
# Epoch 00055: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.0374 - val_accuracy: 0.9897
# Epoch 56/100
# 47808/48000 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9995
# Epoch 00056: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0370 - val_accuracy: 0.9897
# Epoch 57/100
# 47616/48000 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9996
# Epoch 00057: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0051 - accuracy: 0.9996 - val_loss: 0.0369 - val_accuracy: 0.9900
# Epoch 58/100
# 47488/48000 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9995
# Epoch 00058: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0369 - val_accuracy: 0.9901
# Epoch 59/100
# 47360/48000 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9996
# Epoch 00059: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.0368 - val_accuracy: 0.9897
# Epoch 60/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9997
# Epoch 00060: val_loss did not improve from 0.03670
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.0384 - val_accuracy: 0.9892
# Epoch 61/100
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9996
# Epoch 00061: val_loss improved from 0.03670 to 0.03633, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.0363 - val_accuracy: 0.9902
# Epoch 62/100
# 47296/48000 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9997
# Epoch 00062: val_loss did not improve from 0.03633
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0374 - val_accuracy: 0.9897
# Epoch 63/100
# 47744/48000 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9996
# Epoch 00063: val_loss did not improve from 0.03633
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.0375 - val_accuracy: 0.9896
# Epoch 64/100
# 47424/48000 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9997
# Epoch 00064: val_loss did not improve from 0.03633
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.0369 - val_accuracy: 0.9896
# Epoch 65/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9997
# Epoch 00065: val_loss did not improve from 0.03633
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.0368 - val_accuracy: 0.9902
# Epoch 66/100
# 47552/48000 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9997
# Epoch 00066: val_loss did not improve from 0.03633
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.0366 - val_accuracy: 0.9899
# Epoch 67/100
# 47488/48000 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9997
# Epoch 00067: val_loss improved from 0.03633 to 0.03619, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0362 - val_accuracy: 0.9902
# Epoch 68/100
# 47840/48000 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9997
# Epoch 00068: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0368 - val_accuracy: 0.9900
# Epoch 69/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9997
# Epoch 00069: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0371 - val_accuracy: 0.9901
# Epoch 70/100
# 46976/48000 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9997
# Epoch 00070: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0370 - val_accuracy: 0.9903
# Epoch 71/100
# 47360/48000 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9997
# Epoch 00071: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0366 - val_accuracy: 0.9902
# Epoch 72/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9997
# Epoch 00072: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0364 - val_accuracy: 0.9896
# Epoch 73/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9998
# Epoch 00073: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0370 - val_accuracy: 0.9901
# Epoch 74/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9999
# Epoch 00074: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0367 - val_accuracy: 0.9902
# Epoch 75/100
# 47616/48000 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9999
# Epoch 00075: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0031 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9904
# Epoch 76/100
# 47232/48000 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9998
# Epoch 00076: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0370 - val_accuracy: 0.9897
# Epoch 77/100
# 47552/48000 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9998
# Epoch 00077: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0372 - val_accuracy: 0.9902
# Epoch 78/100
# 47648/48000 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9998
# Epoch 00078: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0369 - val_accuracy: 0.9904
# Epoch 79/100
# 47552/48000 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9998
# Epoch 00079: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0368 - val_accuracy: 0.9900
# Epoch 80/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9999
# Epoch 00080: val_loss did not improve from 0.03619
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.0369 - val_accuracy: 0.9904
# Epoch 81/100
# 47168/48000 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998
# Epoch 00081: val_loss improved from 0.03619 to 0.03615, saving model to models/mnist.lenet.best.hdf5
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0362 - val_accuracy: 0.9907
# Epoch 82/100
# 47712/48000 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9999
# Epoch 00082: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.0369 - val_accuracy: 0.9902
# Epoch 83/100
# 47456/48000 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9999
# Epoch 00083: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.0368 - val_accuracy: 0.9898
# Epoch 84/100
# 47360/48000 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9998
# Epoch 00084: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0368 - val_accuracy: 0.9904
# Epoch 85/100
# 47584/48000 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9999
# Epoch 00085: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0369 - val_accuracy: 0.9904
# Epoch 86/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9998
# Epoch 00086: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0368 - val_accuracy: 0.9903
# Epoch 87/100
# 47136/48000 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9999
# Epoch 00087: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.0367 - val_accuracy: 0.9903
# Epoch 88/100
# 47008/48000 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9999
# Epoch 00088: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.0363 - val_accuracy: 0.9902
# Epoch 89/100
# 47328/48000 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9999
# Epoch 00089: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0366 - val_accuracy: 0.9903
# Epoch 90/100
# 47520/48000 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9999
# Epoch 00090: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0375 - val_accuracy: 0.9896
# Epoch 91/100
# 47072/48000 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9999
# Epoch 00091: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0366 - val_accuracy: 0.9904
# Epoch 92/100
# 47904/48000 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9999
# Epoch 00092: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0369 - val_accuracy: 0.9900
# Epoch 93/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9999
# Epoch 00093: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9902
# Epoch 94/100
# 46944/48000 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9999
# Epoch 00094: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9903
# Epoch 95/100
# 47648/48000 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9999
# Epoch 00095: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0370 - val_accuracy: 0.9905
# Epoch 96/100
# 46944/48000 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9906
# Epoch 97/100
# 47264/48000 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9999
# Epoch 00097: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9906
# Epoch 98/100
# 47040/48000 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9903
# Epoch 99/100
# 47168/48000 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9999 E
# Epoch 00099: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.0370 - val_accuracy: 0.9903
# Epoch 100/100
# 47776/48000 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 0.03615
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9905

# %% [markdown]
# ### Plot CV Results

# %% [markdown]
# On a single GPU, 50 epochs take around 2.5 minutes, resulting in a test accuracy of 99.09%, slightly below the same result as for the original LeNet5:

# %%
pd.DataFrame(lenet_history.history)[['accuracy', 'val_accuracy']].plot(figsize=(14,4));

# %% [markdown]
# ### Test Classification Accuracy

# %%
# evaluate test accuracy
lenet_accuracy = lenet5.evaluate(X_test.reshape(-1, 28, 28, 1), y_test, verbose=0)[1]
print('Test accuracy: {:.2%}'.format(lenet_accuracy))
# Out:
# Test accuracy: 99.09%

# %% [markdown]
# ## Summary

# %% [markdown]
# For comparison, a simple two-layer feedforward network achieves only 37.36% test accuracy.
#
# The LeNet5 improvement on MNIST is, in fact, modest. Non-neural methods have also achieved classification accuracies greater than or equal to 99%, including K-Nearest Neighbours or Support Vector Machines. CNNs really shine with more challenging datasets as we will see next.
