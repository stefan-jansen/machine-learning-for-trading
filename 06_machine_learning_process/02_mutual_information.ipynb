# %% [markdown]
# # Using information theory to evaluate features

# %% [markdown]
# The mutual information (MI) between a feature and the outcome is a measure of the mutual dependence between the two variables. It extends the notion of correlation to nonlinear relationships. More specifically, it quantifies the information obtained about one random variable through the other random variable.
#
# The concept of MI is closely related to the fundamental notion of entropy of a random variable. Entropy quantifies the amount of information contained in a random variable. Formally, the mutual information—I(X, Y)—of two random variables, X and Y, is defined as the following:
#
# The sklearn function implements feature_selection.mutual_info_regression that computes the mutual information between all features and a continuous outcome to select the features that are most likely to contain predictive information. There is also a classification version (see the documentation for more details).
#
# This notebook contains an application to the financial data we created in Chapter 4, Alpha Factor Research.

# %%
# %matplotlib inline

import warnings
from datetime import datetime
import os
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_classif

# %%
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
idx = pd.IndexSlice

# %% [markdown]
# ## Get Data

# %% [markdown]
# We use the data produced in [Chapter 4](../../04_alpha_factor_research/00_data/feature_engineering.ipynb).

# %%
with pd.HDFStore('../data/assets.h5') as store:
    data = store['engineered_features']

# %% [markdown]
# ## Create Dummy variables

# %%
dummy_data = pd.get_dummies(data,
                            columns=['year','month', 'msize', 'age',  'sector'],
                            prefix=['year','month', 'msize', 'age', ''],
                            prefix_sep=['_', '_', '_', '_', ''])
dummy_data = dummy_data.rename(columns={c:c.replace('.0', '') for c in dummy_data.columns})
dummy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 327121 entries, ('A', Timestamp('2001-01-31 00:00:00')) to ('ZUMZ', Timestamp('2018-02-28 00:00:00'))
# Data columns (total 87 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   return_1m              327121 non-null  float64
#  1   return_2m              327121 non-null  float64
#  2   return_3m              327121 non-null  float64
#  3   return_6m              327121 non-null  float64
#  4   return_9m              327121 non-null  float64
#  5   return_12m             327121 non-null  float64
#  6   Mkt-RF                 327121 non-null  float64
#  7   SMB                    327121 non-null  float64
#  8   HML                    327121 non-null  float64
#  9   RMW                    327121 non-null  float64
#  10  CMA                    327121 non-null  float64
#  11  momentum_2             327121 non-null  float64
#  12  momentum_3             327121 non-null  float64
#  13  momentum_6             327121 non-null  float64
#  14  momentum_9             327121 non-null  float64
#  15  momentum_12            327121 non-null  float64
#  16  momentum_3_12          327121 non-null  float64
#  17  return_1m_t-1          325451 non-null  float64
#  18  return_1m_t-2          323781 non-null  float64
#  19  return_1m_t-3          322111 non-null  float64
#  20  return_1m_t-4          320441 non-null  float64
#  21  return_1m_t-5          318771 non-null  float64
#  22  return_1m_t-6          317101 non-null  float64
#  23  target_1m              327121 non-null  float64
#  24  target_2m              325451 non-null  float64
#  25  target_3m              323781 non-null  float64
#  26  target_6m              318771 non-null  float64
#  27  target_12m             308751 non-null  float64
#  28  year_2001              327121 non-null  uint8
#  29  year_2002              327121 non-null  uint8
#  30  year_2003              327121 non-null  uint8
#  31  year_2004              327121 non-null  uint8
#  32  year_2005              327121 non-null  uint8
#  33  year_2006              327121 non-null  uint8
#  34  year_2007              327121 non-null  uint8
#  35  year_2008              327121 non-null  uint8
#  36  year_2009              327121 non-null  uint8
#  37  year_2010              327121 non-null  uint8
#  38  year_2011              327121 non-null  uint8
#  39  year_2012              327121 non-null  uint8
#  40  year_2013              327121 non-null  uint8
#  41  year_2014              327121 non-null  uint8
#  42  year_2015              327121 non-null  uint8
#  43  year_2016              327121 non-null  uint8
#  44  year_2017              327121 non-null  uint8
#  45  year_2018              327121 non-null  uint8
#  46  month_1                327121 non-null  uint8
#  47  month_2                327121 non-null  uint8
#  48  month_3                327121 non-null  uint8
#  49  month_4                327121 non-null  uint8
#  50  month_5                327121 non-null  uint8
#  51  month_6                327121 non-null  uint8
#  52  month_7                327121 non-null  uint8
#  53  month_8                327121 non-null  uint8
#  54  month_9                327121 non-null  uint8
#  55  month_10               327121 non-null  uint8
#  56  month_11               327121 non-null  uint8
#  57  month_12               327121 non-null  uint8
#  58  msize_1                327121 non-null  uint8
#  59  msize_2                327121 non-null  uint8
#  60  msize_3                327121 non-null  uint8
#  61  msize_4                327121 non-null  uint8
#  62  msize_5                327121 non-null  uint8
#  63  msize_6                327121 non-null  uint8
#  64  msize_7                327121 non-null  uint8
#  65  msize_8                327121 non-null  uint8
#  66  msize_9                327121 non-null  uint8
#  67  msize_10               327121 non-null  uint8
#  68  age_0                  327121 non-null  uint8
#  69  age_1                  327121 non-null  uint8
#  70  age_2                  327121 non-null  uint8
#  71  age_3                  327121 non-null  uint8
#  72  age_4                  327121 non-null  uint8
#  73  age_5                  327121 non-null  uint8
#  74  Basic Industries       327121 non-null  uint8
#  75  Capital Goods          327121 non-null  uint8
#  76  Consumer Durables      327121 non-null  uint8
#  77  Consumer Non-Durables  327121 non-null  uint8
#  78  Consumer Services      327121 non-null  uint8
#  79  Energy                 327121 non-null  uint8
#  80  Finance                327121 non-null  uint8
#  81  Health Care            327121 non-null  uint8
#  82  Miscellaneous          327121 non-null  uint8
#  83  Public Utilities       327121 non-null  uint8
#  84  Technology             327121 non-null  uint8
#  85  Transportation         327121 non-null  uint8
#  86  Unknown                327121 non-null  uint8
# dtypes: float64(28), uint8(59)
# memory usage: 89.6+ MB

# %% [markdown]
# ## Mutual Information

# %% [markdown]
# ### Original Data

# %%
target_labels = [f'target_{i}m' for i in [1,2,3,6,12]]
targets = data.dropna().loc[:, target_labels]

features = data.dropna().drop(target_labels, axis=1)
features.sector = pd.factorize(features.sector)[0]

cat_cols = ['year', 'month', 'msize', 'age', 'sector']
discrete_features = [features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=features, 
                             y=(targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )
    mutual_info[label] = pd.Series(mi, index=features.columns)

# %%
mutual_info.sum()
# Out:
# target_1m     0.036936
# target_2m     0.062689
# target_3m     0.091033
# target_6m     0.139528
# target_12m    0.203039
# dtype: float64

# %% [markdown]
# ### Normalized MI Heatmap

# %%
fig, ax= plt.subplots(figsize=(15, 4))
sns.heatmap(mutual_info.div(mutual_info.sum()).T, ax=ax, cmap='Blues');

# %% [markdown]
# ### Dummy Data

# %%
target_labels = [f'target_{i}m' for i in [1, 2, 3, 6, 12]]
dummy_targets = dummy_data.dropna().loc[:, target_labels]

dummy_features = dummy_data.dropna().drop(target_labels, axis=1)
cat_cols = [c for c in dummy_features.columns if c not in features.columns]
discrete_features = [dummy_features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info_dummies = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=dummy_features, 
                             y=(dummy_targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )    
    mutual_info_dummies[label] = pd.Series(mi, index=dummy_features.columns)

# %%
mutual_info_dummies.sum()
# Out:
# target_1m     0.038119
# target_2m     0.064659
# target_3m     0.093793
# target_6m     0.143570
# target_12m    0.207894
# dtype: float64

# %%
fig, ax= plt.subplots(figsize=(4, 20))
sns.heatmap(mutual_info_dummies.div(mutual_info_dummies.sum()), ax=ax, cmap='Blues');
