# %% [markdown]
# # Backtesting with zipline - Pipeline API with Custom Data

# %% [markdown]
# ## Imports & Settings

# %%
from collections import defaultdict
from time import time

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from logbook import Logger, StderrHandler, INFO

from zipline import run_algorithm
from zipline.api import (attach_pipeline, pipeline_output,
                         date_rules, time_rules, record,
                         schedule_function, commission, slippage,
                         set_slippage, set_commission,
                         order_target, order_target_percent)
from zipline.data import bundles
from zipline.utils.run_algo import load_extensions
from zipline.pipeline import Pipeline, CustomFactor
from zipline.pipeline.data import Column, DataSet
from zipline.pipeline.domain import JP_EQUITIES
from zipline.pipeline.filters import StaticAssets
from zipline.pipeline.loaders import USEquityPricingLoader
from zipline.pipeline.loaders.frame import DataFrameLoader
from trading_calendars import get_calendar

import pyfolio as pf
from pyfolio.plotting import plot_rolling_returns, plot_rolling_sharpe

# %%
sns.set_style('darkgrid')
np.random.seed(42)

# %% [markdown]
# ### Load zipline extensions

# %% [markdown]
# Only need this in notebook to find bundle.

# %%
load_extensions(default=True,
                extensions=[],
                strict=True,
                environ=None)

# %%
log_handler = StderrHandler(format_string='[{record.time:%Y-%m-%d %H:%M:%S.%f}]: ' +
                            '{record.level_name}: {record.func_name}: {record.message}',
                            level=INFO)
log_handler.push_application()
log = Logger('Algorithm')

# %% [markdown]
# ## Algo Params

# %%
N_LONGS = 50
N_SHORTS = 50
MIN_POSITIONS = 25

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Quandl Wiki Bundel

# %%
bundle_data = bundles.load('stooq')

# %% [markdown]
# ### ML Predictions

# %%
def load_predictions(bundle):
    predictions = (pd.read_hdf('baseline.h5', 'fwd_ret_21/predictions')
                  .rename(columns={'y_pred': 'predictions'}))

    tickers = predictions.index.get_level_values('symbol').unique().tolist()

    assets = bundle.asset_finder.lookup_symbols(tickers, as_of_date=None)
    predicted_sids = pd.Int64Index([asset.sid for asset in assets])
    ticker_map = dict(zip(tickers, predicted_sids))

    return (predictions
            .unstack('symbol')
            .rename(columns=ticker_map)
            .predictions
            .tz_localize('UTC')), assets

# %%
predictions, assets = load_predictions(bundle_data)

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 756 entries, 2016-10-27 to 2019-11-29
# Columns: 940 entries, 1 to 2856
# dtypes: float64(940)
# memory usage: 5.4 MB

# %% [markdown]
# ### Define Custom Dataset

# %%
class SignalData(DataSet):
    predictions = Column(dtype=float)
    domain = JP_EQUITIES

# %% [markdown]
# ### Define Pipeline Loaders

# %%
signal_loader = {SignalData.predictions:
                     DataFrameLoader(SignalData.predictions, predictions)}

# %% [markdown]
# ## Pipeline Setup

# %% [markdown]
# ### Custom ML Factor

# %%
class MLSignal(CustomFactor):
    """Converting signals to Factor
        so we can rank and filter in Pipeline"""
    inputs = [SignalData.predictions]
    window_length = 1

    def compute(self, today, assets, out, preds):
        out[:] = preds

# %% [markdown]
# ### Create Pipeline

# %%
def compute_signals():
    signals = MLSignal()
    predictions = SignalData.predictions.latest
    return Pipeline(columns={
        'longs' : signals.top(N_LONGS, mask=signals > 0),
        'shorts': signals.bottom(N_SHORTS, mask=signals < 0)},
            screen=StaticAssets(assets)
    )

# %% [markdown]
# ## Initialize Algorithm

# %%
def initialize(context):
    """
    Called once at the start of the algorithm.
    """
    context.n_longs = N_LONGS
    context.n_shorts = N_SHORTS
    context.min_positions = MIN_POSITIONS
    context.universe = assets
    context.trades = pd.Series()

    set_slippage(slippage.FixedSlippage(spread=0.00))
    set_commission(commission.PerShare(cost=0.05, min_trade_cost=1))

    schedule_function(rebalance,
                      date_rules.every_day(),
                      time_rules.market_open(hours=1, minutes=30))

    schedule_function(record_vars,
                      date_rules.every_day(),
                      time_rules.market_close())

    pipeline = compute_signals()
    attach_pipeline(pipeline, 'signals')

# %% [markdown]
# ### Get daily Pipeline results

# %%
def before_trading_start(context, data):
    """
    Called every day before market open.
    """
    output = pipeline_output('signals')
    context.trades = (output['longs'].astype(int)
                      .append(output['shorts'].astype(int).mul(-1))
                      .reset_index()
                      .drop_duplicates()
                      .set_index('index')
                      .squeeze())

# %% [markdown]
# ## Define Rebalancing Logic

# %%
def rebalance(context, data):
    """
    Execute orders according to schedule_function() date & time rules.
    """
    trades = defaultdict(list)
    
    for stock, trade in context.trades.items():
        if not trade:
            order_target(stock, 0)
        else:
            trades[trade].append(stock)
    context.longs, context.shorts = len(trades[1]), len(trades[-1])
    if context.longs > context.min_positions and context.shorts > context.min_positions:

        for stock in trades[-1]:
            order_target_percent(stock, -1 / context.shorts)
        for stock in trades[1]:
            order_target_percent(stock, 1 / context.longs)

# %% [markdown]
# ## Record Data Points

# %%
def record_vars(context, data):
    """
    Plot variables at the end of each day.
    """
    record(leverage=context.account.leverage,
           longs=context.longs,
           shorts=context.shorts)

# %% [markdown]
# ## Run Algorithm

# %%
dates = predictions.index.get_level_values('date')
start_date = dates.min() + pd.DateOffset(days=1)
end_date = dates.max()

# %%
start_date.date(), end_date.date()
# Out:
# (datetime.date(2016, 10, 28), datetime.date(2019, 11, 29))

# %%
start = time()
results = run_algorithm(start=start_date,
                        end=end_date,
                        initialize=initialize,
                        before_trading_start=before_trading_start,
                        capital_base=1e6,
                        data_frequency='daily',
                        bundle='stooq',
                        custom_loader=signal_loader)  # need to modify zipline

print('Duration: {:.2f}s'.format(time() - start))
# Out:
# [2020-02-02 19:59:43.082925]: WARNING: _load_cached_data: Refusing to download new benchmark data because a download succeeded at 2020-02-02 19:57:08.312736+00:00.
# [2020-02-02 19:59:43.119137]: WARNING: _load_cached_data: Refusing to download new treasury data because a download succeeded at 2020-02-02 19:57:08.840737+00:00.
# [2020-02-02 20:00:51.510583]: INFO: handle_simulation_end: Simulated 777 trading days
# first open: 2016-10-28 13:31:00+00:00
# last close: 2019-11-29 18:00:00+00:00
# Duration: 68.46s

# %% [markdown]
# ## PyFolio Analysis

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)

# %%
benchmark = web.DataReader('NIKKEI225', 'fred', '2014', '2020').squeeze()
benchmark = benchmark.pct_change().tz_localize('UTC')

# %% [markdown]
# ### Custom Plots

# %%
fig, axes = plt.subplots(ncols=2, figsize=(16, 5))
plot_rolling_returns(returns,
                     factor_returns=benchmark,
                     live_start_date='2018-10-15',
                     logy=False,
                     cone_std=2,
                     legend_loc='best',
                     volatility_match=False,
                     cone_function=timeseries.forecast_cone_bootstrap,
                    ax=axes[0])
plot_rolling_sharpe(returns, ax=axes[1])
axes[0].set_title('Cumulative Returns - In and Out-of-Sample')
fig.tight_layout()
fig.savefig('figures/pyfolio', dpi=300);

# %% [markdown]
# ### Tear Sheets

# %%
pf.create_full_tear_sheet(returns, 
                          positions=positions, 
                          transactions=transactions,
                          benchmark_rets=benchmark,
                          live_start_date='2018-10-15', 
                          round_trips=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2016-10-28</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2019-11-29</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>23</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>13</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>All</th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>24.5%</td>
#       <td>22.1%</td>
#       <td>29.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>96.8%</td>
#       <td>47.7%</td>
#       <td>33.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>9.0%</td>
#       <td>8.7%</td>
#       <td>9.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.47</td>
#       <td>2.34</td>
#       <td>2.68</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.95</td>
#       <td>3.50</td>
#       <td>3.48</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#       <td>0.91</td>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.3%</td>
#       <td>-6.3%</td>
#       <td>-8.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.78</td>
#       <td>1.78</td>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>4.35</td>
#       <td>3.97</td>
#       <td>4.98</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.80</td>
#       <td>0.54</td>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>6.80</td>
#       <td>7.64</td>
#       <td>5.55</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.58</td>
#       <td>1.72</td>
#       <td>1.51</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.0%</td>
#       <td>-1.0%</td>
#       <td>-1.1%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.07</td>
#       <td>1.08</td>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>178.5%</td>
#       <td>179.6%</td>
#       <td>177.3%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.25</td>
#       <td>0.22</td>
#       <td>0.29</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.09</td>
#       <td>-0.05</td>
#       <td>-0.16</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.32</td>
#       <td>2019-08-02</td>
#       <td>2019-11-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.30</td>
#       <td>2016-11-07</td>
#       <td>2016-12-12</td>
#       <td>2017-03-21</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.27</td>
#       <td>2017-08-29</td>
#       <td>2018-02-09</td>
#       <td>2018-02-15</td>
#       <td>123</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.68</td>
#       <td>2018-10-01</td>
#       <td>2018-10-11</td>
#       <td>2018-10-23</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.14</td>
#       <td>2019-01-04</td>
#       <td>2019-01-25</td>
#       <td>2019-02-01</td>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.09%</td>
#       <td>-2.89%</td>
#       <td>3.35%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2492.JP</th>
#       <td>5.94%</td>
#     </tr>
#     <tr>
#       <th>3756.JP</th>
#       <td>5.54%</td>
#     </tr>
#     <tr>
#       <th>3254.JP</th>
#       <td>5.31%</td>
#     </tr>
#     <tr>
#       <th>3660.JP</th>
#       <td>5.12%</td>
#     </tr>
#     <tr>
#       <th>2120.JP</th>
#       <td>5.02%</td>
#     </tr>
#     <tr>
#       <th>3046.JP</th>
#       <td>4.94%</td>
#     </tr>
#     <tr>
#       <th>6088.JP</th>
#       <td>4.90%</td>
#     </tr>
#     <tr>
#       <th>2489.JP</th>
#       <td>4.47%</td>
#     </tr>
#     <tr>
#       <th>3774.JP</th>
#       <td>4.07%</td>
#     </tr>
#     <tr>
#       <th>6817.JP</th>
#       <td>3.98%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4506.JP</th>
#       <td>-6.19%</td>
#     </tr>
#     <tr>
#       <th>2120.JP</th>
#       <td>-6.11%</td>
#     </tr>
#     <tr>
#       <th>8897.JP</th>
#       <td>-4.85%</td>
#     </tr>
#     <tr>
#       <th>2440.JP</th>
#       <td>-4.79%</td>
#     </tr>
#     <tr>
#       <th>8714.JP</th>
#       <td>-4.76%</td>
#     </tr>
#     <tr>
#       <th>2193.JP</th>
#       <td>-4.72%</td>
#     </tr>
#     <tr>
#       <th>9449.JP</th>
#       <td>-4.62%</td>
#     </tr>
#     <tr>
#       <th>8361.JP</th>
#       <td>-4.61%</td>
#     </tr>
#     <tr>
#       <th>4755.JP</th>
#       <td>-4.58%</td>
#     </tr>
#     <tr>
#       <th>9509.JP</th>
#       <td>-4.58%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4506.JP</th>
#       <td>6.19%</td>
#     </tr>
#     <tr>
#       <th>2120.JP</th>
#       <td>6.11%</td>
#     </tr>
#     <tr>
#       <th>2492.JP</th>
#       <td>5.94%</td>
#     </tr>
#     <tr>
#       <th>3756.JP</th>
#       <td>5.54%</td>
#     </tr>
#     <tr>
#       <th>3254.JP</th>
#       <td>5.31%</td>
#     </tr>
#     <tr>
#       <th>3660.JP</th>
#       <td>5.12%</td>
#     </tr>
#     <tr>
#       <th>3046.JP</th>
#       <td>4.94%</td>
#     </tr>
#     <tr>
#       <th>6088.JP</th>
#       <td>4.90%</td>
#     </tr>
#     <tr>
#       <th>8897.JP</th>
#       <td>4.85%</td>
#     </tr>
#     <tr>
#       <th>2440.JP</th>
#       <td>4.79%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>34738.00</td>
#       <td>17493.00</td>
#       <td>17245.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.50</td>
#       <td>0.51</td>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>17479.00</td>
#       <td>8845.00</td>
#       <td>8634.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>16341.00</td>
#       <td>8139.00</td>
#       <td>8202.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>918.00</td>
#       <td>509.00</td>
#       <td>409.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>
th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6920.JP</th>
#       <td>3.49%</td>
#     </tr>
#     <tr>
#       <th>4506.JP</th>
#       <td>3.02%</td>
#     </tr>
#     <tr>
#       <th>3793.JP</th>
#       <td>2.07%</td>
#     </tr>
#     <tr>
#       <th>3186.JP</th>
#       <td>1.91%</td>
#     </tr>
#     <tr>
#       <th>6324.JP</th>
#       <td>1.83%</td>
#     </tr>
#     <tr>
#       <th>2120.JP</th>
#       <td>1.70%</td>
#     </tr>
#     <tr>
#       <th>3665.JP</th>
#       <td>1.60%</td>
#     </tr>
#     <tr>
#       <th>9419.JP</th>
#       <td>1.53%</td>
#     </tr>
#     <tr>
#       <th>2317.JP</th>
#       <td>1.52%</td>
#     </tr>
#     <tr>
#       <th>2395.JP</th>
#       <td>1.50%</td>
#     </tr>
#     <tr>
#       <th>3655.JP</th>
#       <td>1.47%</td>
#     </tr>
#     <tr>
#       <th>2412.JP</th>
#       <td>1.44%</td>
#     </tr>
#     <tr>
#       <th>2170.JP</th>
#       <td>1.41%</td>
#     </tr>
#     <tr>
#       <th>6444.JP</th>
#       <td>1.39%</td>
#     </tr>
#     <tr>
#       <th>6141.JP</th>
#       <td>1.36%</td>
#     </tr>
#     <tr>
#       <th>2685.JP</th>
#       <td>1.35%</td>
#     </tr>
#     <tr>
#       <th>7744.JP</th>
#       <td>1.24%</td>
#     </tr>
#     <tr>
#       <th>6050.JP</th>
#       <td>1.21%</td>
#     </tr>
#     <tr>
#       <th>6630.JP</th>
#       <td>1.15%</td>
#     </tr>
#     <tr>
#       <th>6958.JP</th>
#       <td>1.13%</td>
#     </tr>
#     <tr>
#       <th>4348.JP</th>
#       <td>1.12%</td>
#     </tr>
#     <tr>
#       <th>7242.JP</th>
#       <td>1.07%</td>
#     </tr>
#     <tr>
#       <th>4978.JP</th>
#       <td>1.07%</td>
#     </tr>
#     <tr>
#       <th>3659.JP</th>
#       <td>1.06%</td>
#     </tr>
#     <tr>
#       <th>2706.JP</th>
#       <td>1.05%</td>
#     </tr>
#     <tr>
#       <th>3038.JP</th>
#       <td>1.04%</td>
#     </tr>
#     <tr>
#       <th>6366.JP</th>
#       <td>1.03%</td>
#     </tr>
#     <tr>
#       <th>4633.JP</th>
#       <td>1.01%</td>
#     </tr>
#     <tr>
#       <th>7014.JP</th>
#       <td>1.00%</td>
#     </tr>
#     <tr>
#       <th>6804.JP</th>
#       <td>0.99%</td>
#     </tr>
#     <tr>
#       <th>3762.JP</th>
#       <td>0.99%</td>
#     </tr>
#     <tr>
#       <th>5563.JP</th>
#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <th>2138.JP</th>
#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <th>6440.JP</th>
#       <td>0.97%</td>
#     </tr>
#     <tr>
#       <th>6222.JP</th>
#       <td>0.97%</td>
#     </tr>
#     <tr>
#       <th>2193.JP</th>
#       <td>0.96%</td>
#     </tr>
#     <tr>
#       <th>8892.JP</th>
#       <td>0.96%</td>
#     </tr>
#     <tr>
#       <th>6754.JP</th>
#       <td>0.96%</td>
#     </tr>
#     <tr>
#       <th>4971.JP</th>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <th>2484.JP</th>
#       <td>0.93%</td>
#     </tr>
#     <tr>
#       <th>4686.JP</th>
#       <td>0.88%</td>
#     </tr>
#     <tr>
#       <th>6058.JP</th>
#       <td>0.87%</td>
#     </tr>
#     <tr>
#       <th>6407.JP</th>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>6269.JP</th>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>6817.JP</th>
#       <td>0.85%</td>
#     </tr>
#     <tr>
#       <th>6118.JP</th>
#       <td>0.84%</td>
#     </tr>
#     <tr>
#       <th>9501.JP</th>
#       <td>0.83%</td>
#     </tr>
#     <tr>
#       <th>6080.JP</th>
#       <td>0.81%</td>
#     </tr>
#     <tr>
#       <th>6486.JP</th>
#       <td>0.80%</td>
#     </tr>
#     <tr>
#       <th>3678.JP</th>
#       <td>0.80%</td>
#     </tr>
#     <tr>
#       <th>7832.JP</th>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <th>6463.JP</th>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <th>6794.JP</th>
#       <td>0.77%</td>
#     </tr>
#     <tr>
#       <th>3284.JP</th>
#       <td>0.75%</td>
#     </tr>
#     <tr>
#       <th>6844.JP</th>
#       <td>0.74%</td>
#     </tr>
#     <tr>
#       <th>7244.JP</th>
#       <td>0.74%</td>
#     </tr>
#     <tr>
#       <th>5726.JP</th>
#       <td>0.73%</td>
#     </tr>
#     <tr>
#       <th>6471.JP</th>
#       <td>0.72%</td>
#     </tr>
#     <tr>
#       <th>4109.JP</th>
#       <td>0.69%</td>
#     </tr>
#     <tr>
#       <th>9533.JP</th>
#       <td>0.69%</td>
#     </tr>
#     <tr>
#       <th>6480.JP</th>
#       <td>0.67%</td>
#     </tr>
#     <tr>
#       <th>4581.JP</th>
#       <td>0.65%</td>
#     </tr>
#     <tr>
#       <th>4571.JP</th>
#       <td>0.64%</td>
#     </tr>
#     <tr>
#       <th>5480.JP</th>
#       <td>0.63%</td>
#     </tr>
#     <tr>
#       <th>6315.JP</th>
#       <td>0.63%</td>
#     </tr>
#     <tr>
#       <th>6753.JP</th>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <th>2802.JP</th>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <th>5706.JP</th>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <th>8379.JP</th>
#       <td>0.61%</td>
#     </tr>
#     <tr>
#       <th>4714.JP</th>
#       <td>0.61%</td>
#     </tr>
#     <tr>
#       <th>4751.JP</th>
#       <td>0.61%</td>
#     </tr>
#     <tr>
#       <th>4919.JP</th>
#       <td>0.60%</td>
#     </tr>
#     <tr>
#       <th>3676.JP</th>
#       <td>0.60%</td>
#     </tr>
#     <tr>
#       <th>3769.JP</th>
#       <td>0.60%</td>
#     </tr>
#     <tr>
#       <th>4568.JP</th>
#       <td>0.58%</td>
#     </tr>
#     <tr>
#       <th>4617.JP</th>
#       <td>0.58%</td>
#     </tr>
#     <tr>
#       <th>6289.JP</th>
#       <td>0.57%</td>
#     </tr>
#     <tr>
#       <th>2931.JP</th>
#       <td>0.56%</td>
#     </tr>
#     <tr>
#       <th>1407.JP</th>
#       <td>0.55%</td>
#     </tr>
#     <tr>
#       <th>6473.JP</th>
#       <td>0.55%</td>
#     </tr>
#     <tr>
#       <th>1662.JP</th>
#       <td>0.55%</td>
#     </tr>
#     <tr>
#       <th>7272.JP</th>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>5809.JP</th>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>6723.JP</th>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>2681.JP</th>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>8028.JP</th>
#       <td>0.53%</td>
#     </tr>
#     <tr>
#       <th>4112.JP</th>
#       <td>0.53%</td>
#     </tr>
#     <tr>
#       <th>4514.JP</th>
#       <td>0.52%</td>
#     </tr>
#     <tr>
#       <th>7867.JP</th>
#       <td>0.52%</td>
#     </tr>
#     <tr>
#       <th>6460.JP</th>
#       <td>0.51%</td>
#     </tr>
#     <tr>
#       <th>8739.JP</th>
#       <td>0.51%</td>
#     </tr>
#     <tr>
#       <th>4849.JP</th>
#       <td>0.51%</td>
#     </tr>
#     <tr>
#       <th>5857.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>4182.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>9684.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>2782.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>7732.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>5949.JP</th>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <th>8078.JP</th>
#       <td>0.49%</td>
#     </tr>
#     <tr>
#       <th>9716.JP</th>
#       <td>0.48%</td>
#     </tr>
#     <tr>
#       <th>4461.JP</th>
#       <td>0.47%</td>
#     </tr>
#     <tr>
#       <th>9792.JP</th>
#       <td>0.47%</td>
#     </tr>
#     <tr>
#       <th>2146.JP</th>
#       <td>0.45%</td>
#     </tr>
#     <tr>
#       <th>6807.JP</th>
#       <td>0.45%</td>
#     </tr>
#     <tr>
#       <th>1885.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>7261.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>2428.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>8714.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>9627.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>5344.JP</th>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>8609.JP</th>
#       <td>0.43%</td>
#     </tr>
#     <tr>
#       <th>8876.JP</th>
#       <td>0.43%</td>
#     </tr>
#     <tr>
#       <th>6077.JP</th>
#       <td>0.43%</td>
#     </tr>
#     <tr>
#       <th>6724.JP</th>
#       <td>0.43%</td>
#     </tr>
#     <tr>
#       <th>4555.JP</th>
#       <td>0.43%</td>
#     </tr>
#     <tr>
#       <th>9449.JP</th>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <th>2379.JP</th>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <th>6966.JP</th>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <th>2175.JP</th>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>4921.JP</th>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>4708.JP</th>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>4974.JP</th>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>5481.JP</th>
#       <td>0.40%</td>
#     </tr>
#     <tr>
